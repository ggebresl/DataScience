# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/Salaries.csv')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
# rank          78 non-null object
# discipline    78 non-null object
# phd           78 non-null int64
# service       78 non-null int64
# sex           78 non-null object
# salary        78 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 3.7+ KB

# %%
#df.values

# %%
#df.head()
df.head(6)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800
# 5  Prof          A   20       20  Male  122400

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
# rank          78 non-null object
# discipline    78 non-null object
# phd           78 non-null int64
# service       78 non-null int64
# sex           78 non-null object
# salary        78 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 3.7+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
df.size
# Out:
# 468

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.sample(10, random_state=1)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 77       Prof          A   23       15  Female  109646
# 44       Prof          B   23       19  Female  151768
# 27       Prof          A   45       43    Male  155865
# 63       Prof          A   29       27  Female   91000
# 73       Prof          B   18       10  Female  105450
# 61  AssocProf          B   13       10  Female  103750
# 55   AsstProf          A    2        0  Female   72500
# 51       Prof          B   20       14  Female  127512
# 34  AssocProf          B   12        8    Male  119800

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.head(50).mean()
# Out:
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df['sex'].head()
# Out:
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: sex, dtype: object

# %%
df.sex.head()
# Out:
# 0    Male
# 1    Male
# 2    Male
# 3    Male
# 4    Male
# Name: sex, dtype: object

# %%
df[['sex','salary']].head()
# Out:
#     sex  salary
# 0  Male  186960
# 1  Male   93000
# 2  Male  110515
# 3  Male  131205
# 4  Male  104800

# %%
df['salary'].describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df['salary'].count()
# Out:
# 78

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
set(df['rank'])
# Out:
# {'AssocProf', 'AsstProf', 'Prof'}

# %%
groupRank = df.groupby(['rank'])

# %%
groupRank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
groupRank = df[['rank','salary']].groupby(['rank'])

# %%
groupRank.mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df.groupby(['rank'],sort=True)[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df[(df['salary']>100000) & (df['rank']=='AssocProf')]
# Out:
#          rank discipline  phd  service     sex  salary
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 47  AssocProf          B   11       11  Female  103613
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 74  AssocProf          B   19        6  Female  104542

# %%
df[df['rank']=='AssocProf'].count()
# Out:
# rank          13
# discipline    13
# phd           13
# service       13
# sex           13
# salary        13
# dtype: int64

# %%
df.sort_values(by='salary',ascending=False).head()
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 13  Prof          B   35       33    Male  162200
# 72  Prof          B   24       15  Female  161101
# 27  Prof          A   45       43    Male  155865
# 31  Prof          B   22       21    Male  155750

# %%
df.sort_values(by = ['service','salary'], ascending=[True,False]).head()
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000

# %%
df1 = pd.read_csv('dataset/flights.csv')
df1.head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0  2013.0    1.0  1.0     517.0        2.0     830.0       11.0      UA
# 1  2013.0    1.0  1.0     533.0        4.0     850.0       20.0      UA
# 2     NaN    NaN  NaN       NaN        NaN       NaN        NaN     NaN
# 3  2013.0    1.0  1.0     542.0        2.0     923.0       33.0      AA
# 4  2013.0    1.0  1.0     554.0       -6.0     812.0      -25.0      DL
#
#   tailnum  flight origin dest  air_time  distance  hour  minute
# 0  N14228  1545.0    EWR  IAH     227.0    1400.0   5.0    17.0
# 1  N24211  1714.0    LGA  IAH     227.0    1416.0   5.0    33.0
# 2     NaN     NaN    NaN  NaN       NaN       NaN   NaN     NaN
# 3  N619AA  1141.0    JFK  MIA     160.0    1089.0   5.0    42.0
# 4  N668DN   461.0    LGA  ATL     116.0     762.0   5.0    54.0

# %%
len(df1.columns)
# Out:
# 16

# %%
df1.shape
# Out:
# (160757, 16)

# %%
df1.isnull().any()
# Out:
# year         True
# month        True
# day          True
# dep_time     True
# dep_delay    True
# arr_time     True
# arr_delay    True
# carrier      True
# tailnum      True
# flight       True
# origin       True
# dest         True
# air_time     True
# distance     True
# hour         True
# minute       True
# dtype: bool

# %%
df1.isnull().sum()
# Out:
# year            3
# month           3
# day             3
# dep_time     2339
# dep_delay    2339
# arr_time     2482
# arr_delay    2830
# carrier         3
# tailnum      1436
# flight          3
# origin          3
# dest            3
# air_time     2830
# distance        3
# hour         2339
# minute       2339
# dtype: int64

# %%
df1.isnull().all(axis=1).head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df1[df1.isnull().all(axis=1)]
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 2   NaN    NaN  NaN       NaN        NaN       NaN        NaN     NaN     NaN
# 5   NaN    NaN  NaN       NaN        NaN       NaN        NaN     NaN     NaN
# 8   NaN    NaN  NaN       NaN        NaN       NaN        NaN     NaN     NaN
#
#    flight origin dest  air_time  distance  hour  minute
# 2     NaN    NaN  NaN       NaN       NaN   NaN     NaN
# 5     NaN    NaN  NaN       NaN       NaN   NaN     NaN
# 8     NaN    NaN  NaN       NaN       NaN   NaN     NaN

# %%
df1.dropna(axis=0, how='all',inplace=True)

# %%
df1.head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0  2013.0    1.0  1.0     517.0        2.0     830.0       11.0      UA
# 1  2013.0    1.0  1.0     533.0        4.0     850.0       20.0      UA
# 3  2013.0    1.0  1.0     542.0        2.0     923.0       33.0      AA
# 4  2013.0    1.0  1.0     554.0       -6.0     812.0      -25.0      DL
# 6  2013.0    1.0  1.0     554.0       -4.0     740.0       12.0      UA
#
#   tailnum  flight origin dest  air_time  distance  hour  minute
# 0  N14228  1545.0    EWR  IAH     227.0    1400.0   5.0    17.0
# 1  N24211  1714.0    LGA  IAH     227.0    1416.0   5.0    33.0
# 3  N619AA  1141.0    JFK  MIA     160.0    1089.0   5.0    42.0
# 4  N668DN   461.0    LGA  ATL     116.0     762.0   5.0    54.0
# 6  N39463  1696.0    EWR  ORD     150.0     719.0   5.0    54.0

# %%
df1[df1.isnull().any(axis=1)].head()
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 333  2013.0    1.0  1.0    1807.0       29.0    2251.0        NaN      UA
# 406  2013.0    1.0  1.0       NaN        NaN       NaN        NaN      AA
# 407  2013.0    1.0  1.0       NaN        NaN       NaN        NaN      AA
# 858  2013.0    1.0  2.0    2145.0       16.0       NaN        NaN      UA
# 861  2013.0    1.0  2.0       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 333  N31412  1228.0    EWR  SAN       NaN    2425.0  18.0     7.0
# 406  N3EHAA   791.0    LGA  DFW       NaN    1389.0   NaN     NaN
# 407  N3EVAA  1925.0    LGA  MIA       NaN    1096.0   NaN     NaN
# 858  N12221  1299.0    EWR  RSW       NaN    1068.0  21.0    45.0
# 861     NaN   133.0    JFK  LAX       NaN    2475.0   NaN     NaN

# %%
filled = df1.fillna(0)
filled[330:1000].head()
# Out:
#        year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 333  2013.0    1.0  1.0    1807.0       29.0    2251.0        0.0      UA
# 334  2013.0    1.0  1.0    1808.0       -7.0    2111.0      -19.0      AS
# 335  2013.0    1.0  1.0    1811.0       12.0    2132.0       14.0      UA
# 336  2013.0    1.0  1.0    1816.0       16.0    2101.0       11.0      UA
# 337  2013.0    1.0  1.0    1817.0       -3.0    2008.0        3.0      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 333  N31412  1228.0    EWR  SAN       0.0    2425.0  18.0     7.0
# 334  N553AS     7.0    EWR  SEA     336.0    2402.0  18.0     8.0
# 335  N482UA   618.0    EWR  DFW     228.0    1372.0  18.0    11.0
# 336  N522UA   638.0    EWR  LAS     307.0    2227.0  18.0    16.0
# 337  N3AXAA   353.0    LGA  ORD     138.0     733.0  18.0    17.0

# %%
df1.fillna(0,inplace=True)
df1[330:1000]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 333   2013.0    1.0  1.0    1807.0       29.0    2251.0        0.0      UA
# 334   2013.0    1.0  1.0    1808.0       -7.0    2111.0      -19.0      AS
# 335   2013.0    1.0  1.0    1811.0       12.0    2132.0       14.0      UA
# 336   2013.0    1.0  1.0    1816.0       16.0    2101.0       11.0      UA
# 337   2013.0    1.0  1.0    1817.0       -3.0    2008.0        3.0      AA
# 338   2013.0    1.0  1.0    1820.0        0.0    2216.0       26.0      AA
# 339   2013.0    1.0  1.0    1823.0       -7.0    2036.0      -19.0      DL
# 340   2013.0    1.0  1.0    1824.0       -6.0    2203.0       -2.0      AA
# 341   2013.0    1.0  1.0    1825.0       -4.0    2046.0       14.0      US
# 342   2013.0    1.0  1.0    1826.0       16.0    2132.0        2.0      AA
# 343   2013.0    1.0  1.0    1826.0       -4.0    2154.0      -13.0      DL
# ...
